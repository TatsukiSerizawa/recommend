# %% [markdown]
# # アニメデータセットを作成1
#
# Kaggleから作品ごとの評価データを取得して成形
# https://www.kaggle.com/datasets/CooperUnion/anime-recommendations-database

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/anime.csv")

# %%
df.shape
# Out:
# (12294, 7)

# %% [markdown]
# ratingは各作品の平均評価値、membersは評価を投稿した人数

# %%
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df.sort_values("rating", ascending=False).head(10)
# Out:
#        anime_id                                     name  \
# 10464     33662  Taka no Tsume 8: Yoshida-kun no X-Files
# 10400     30120              Spoon-hime no Swing Kitchen
# 9595      23005                         Mogura no Motoro
# 0         32281                           Kimi no Na wa.
# 9078      33607                             Kahei no Umi
# 1          5114         Fullmetal Alchemist: Brotherhood
# 2         28977                                 Gintama°
# 10786     26313          Yakusoku: Africa Mizu to Midori
# 3          9253                              Steins;Gate
# 4          9969                            Gintama&#039;
#
#                                                    genre   type episodes  \
# 10464                                     Comedy, Parody  Movie        1
# 10400                                    Adventure, Kids     TV  Unknown
# 9595                                       Slice of Life  Movie        1
# ...

# %%
df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %% [markdown]
# 自分の興味のある作品があるか確認 (あとで評価用にデータセットを作るため)

# %%
df[df["name"].str.contains("code geass", case=False)]
# Out:
#        anime_id                                               name  \
# 13         2904                 Code Geass: Hangyaku no Lelouch R2
# 19         1575                    Code Geass: Hangyaku no Lelouch
# 574        6768  Code Geass: Hangyaku no Lelouch R2 Special Edi...
# 721       15197  Code Geass: Boukoku no Akito 2 - Hikisakareshi...
# 885        4596  Code Geass: Hangyaku no Lelouch Special Editio...
# 1132       8888  Code Geass: Boukoku no Akito 1 - Yokuryuu wa M...
# 1308      15199  Code Geass: Boukoku no Akito 3 - Kagayaku Mono...
# 1406      15201  Code Geass: Boukoku no Akito 4 - Nikushimi no ...
# 1441      23359  Code Geass: Boukoku no Akito 2 - Hikisakareshi...
# 2359      30711  Code Geass: Boukoku no Akito Final - Itoshiki ...
# 2471       5163   Code Geass: Hangyaku no Lelouch R2 Picture Drama
# 2511      31145  Code Geass: Boukoku no Akito 3 - Kagayaku Mono...
# 2938       2124             Code Geass: Hangyaku no Lelouch Recaps
# ...

# %%
df[df["name"].str.contains("toradora", case=False)]
# Out:
#       anime_id                        name  \
# 131       4224                   Toradora!
# 1022     23701               Toradora! OVA
# 1460     11553  Toradora!: Bentou no Gokui
# 5574      6127             Toradora!: SOS!
#
#                                        genre     type episodes  rating  \
# 131   Comedy, Romance, School, Slice of Life       TV       25    8.45
# 1022  Comedy, Romance, School, Slice of Life      OVA        1    7.72
# 1460  Comedy, Romance, School, Slice of Life  Special        1    7.54
# 5574                                  Comedy  Special        4    6.42
#
#       members
# 131    633817
# 1022    25154
# 1460    71433
# 5574    54096

# %%
df[df["name"].str.contains("steins", case=False)]
# Out:
#        anime_id                                               name  \
# 3          9253                                        Steins;Gate
# 59        11577         Steins;Gate Movie: Fuka Ryouiki no Déjà vu
# 126       10863              Steins;Gate: Oukoubakko no Poriomania
# 196       32188  Steins;Gate: Kyoukaimenjou no Missing Link - D...
# 1770      27957   Steins;Gate: Soumei Eichi no Cognitive Computing
# 10898     30484                                      Steins;Gate 0
#
#                   genre     type episodes  rating  members
# 3      Sci-Fi, Thriller       TV       24    9.17   673572
# 59     Sci-Fi, Thriller    Movie        1    8.61   192424
# 126    Sci-Fi, Thriller  Special        1    8.46   159548
# 196    Sci-Fi, Thriller  Special        1    8.34    38147
# 1770             Comedy      ONA        4    7.45    34426
# 10898  Sci-Fi, Thriller      NaN  Unknown     NaN    60999

# %%
df[df["name"].str.contains("doraemon", case=False)]
# Out:
#        anime_id                                               name  \
# 399       21469                               Stand By Me Doraemon
# 929        2471                                    Doraemon (1979)
# 993       10534  Doraemon Movie 31: Shin Nobita to Tetsujin Hei...
# 1160       2673  Doraemon Movie 27: Nobita no Shin Makai Daibou...
# 1309       8687                                    Doraemon (2005)
# ...         ...                                                ...
# 4860       2626     The☆Doraemons: Mushimushi Pyonpyon Daisakusen!
# 4940       2637                        Doraemon: It&#039;s Autumn!
# 5052      16702                     Doraemon: Nobita to Mirai Note
# 5377       2631                  The☆Doraemons: Goal! Goal! Goal!!
# 10972     33672  Doraemon Movie 37: Nobita no Nankyoku Kachikoc...
#
#                                                    genre     type episodes  \
# 399                        Comedy, Kids, Sci-Fi, Shounen    Movie        1
# ...

# %%
df[df["name"].str.contains("shiroba", case=False)]
# Out:
#       anime_id                name              genre     type episodes  \
# 110      25835           Shirobako      Comedy, Drama       TV       24
# 3312     28105  Shirobako Specials  Adventure, Comedy  Special        2
#
#       rating  members
# 110     8.49   146895
# 3312    7.03    11669

# %%
df[df["name"].str.contains("glasslip", case=False)]
# Out:
#       anime_id      name                                 genre type episodes  \
# 7325     23079  Glasslip  Romance, Slice of Life, Supernatural   TV       13
#
#       rating  members
# 7325    5.54    94108

# %%
df[df["name"].str.contains("byousoku", case=False)]
# Out:
#       anime_id                   name                          genre   type  \
# 411       1689  Byousoku 5 Centimeter  Drama, Romance, Slice of Life  Movie
# 6495      4097  Nanmu Ichibyousokusai              Historical, Music  Movie
#
#      episodes  rating  members
# 411         3    8.10   324035
# 6495        1    6.09      251

# %%
# 1万人以上の投票ユーザに絞る
df = df[df["members"] >= 10000]

# %%
df.dropna(inplace=True)

# %%
df.sort_values("rating", ascending=False).head(20)
# Out:
#     anime_id                                               name  \
# 0      32281                                     Kimi no Na wa.
# 1       5114                   Fullmetal Alchemist: Brotherhood
# 2      28977                                           Gintama°
# 3       9253                                        Steins;Gate
# 4       9969                                      Gintama&#039;
# 5      32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6      11061                             Hunter x Hunter (2011)
# 7        820                               Ginga Eiyuu Densetsu
# 9      15417                           Gintama&#039;: Enchousen
# 8      15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 10      4181                               Clannad: After Story
# 11     28851                                     Koe no Katachi
# 12       918                                            Gintama
# 13      2904                 Code Geass: Hangyaku no Lelouch R2
# ...

# %%
df.shape
# Out:
# (2946, 7)

# %%
df.to_csv("../data/preprocessed_anime.csv", index=False)
